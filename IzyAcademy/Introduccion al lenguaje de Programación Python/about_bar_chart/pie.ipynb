# %%
""" 
Un grafico circular es adecuado para mostrar la distribución proporcional
de elementos dentro de la misma categoria, comparar areas, porciones, etc.

Recomiendas:
1. No usar mas de 5 divisiones
2. Colocar el label junto al segmento
3. Usar coloboración de acuerdo con el objetivo de comunicación
"""
# Out:
# ' \nUn grafico circular es adecuado para mostrar la distribución proporcional\nde elementos dentro de la misma categoria, comparar areas, porciones, etc.\n\nRecomiendas:\n1. No usar mas de 5 divisiones\n2. Colocar el label junto al segmento\n3. Usar coloboración de acuerdo con el objetivo de comunicación\n'

# %%
import matplotlib.pyplot as plt

# Definiendo data

app = ['TikTok', 'Whatsapp', 'Facebook', 'Instagram', 'Zoom'];
downloads = [850, 600, 540, 503, 477];

apps = ['TikTok', 'Whatsapp', 'Facebook', 'Instagram', 'Zoom']
plt.pie(porcentaje_downloads, labels=apps, autopct="%0.if", explode=[0.1, 0, 0, 0, 0])
plt.title("Apps más descargas en el 2020")
plt.show()
